# %%
import pandas as pd

# %%
df = pd.read_csv('./fact_sales_mstr.csv')

# %%
df
# Out:
#       Row_ID        Order_ID Customer_ID       Product_ID  ship_ID  \
# 0          1  CA-2016-152156    CG-12520  FUR-BO-10001798        1
# 1          3  CA-2016-138688    DV-13045  OFF-LA-10000240        1
# 2          4  US-2015-108966    SO-20335  FUR-TA-10000577        2
# 3          6  CA-2014-115812    BH-11710  FUR-FU-10001487        2
# 4         13  CA-2017-114412    AA-10480  OFF-PA-10002365        2
# ...      ...             ...         ...              ...      ...
# 5004    9987  CA-2016-125794    ML-17410  TEC-AC-10003399        2
# 5005    9988  CA-2017-163629    RA-19885  TEC-AC-10001539        2
# 5006    9990  CA-2014-110422    TB-21400  FUR-FU-10001889        1
# 5007    9991  CA-2017-121258    DB-13060  FUR-FU-10000747        2
# 5008    9994  CA-2017-119914    CC-12220  OFF-AP-10002684        1
#
#       Category_ID  City_ID     Sales  Quantity  Discount    Profit
# 0               1        1  261.9600         2      0.00   41.9136
# ...

# %%
df.columns
# Out:
# Index(['Row_ID', 'Order_ID', 'Customer_ID', 'Product_ID', 'ship_ID',
#        'Category_ID', 'City_ID', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5004    False
# 5005    False
# 5006    False
# 5007    False
# 5008    False
# Length: 5009, dtype: bool

# %%
fact_sales_mstr = 'fact_sales_mstr'

# %%
for indice, fila in df.iterrows():
    valores = ', '.join([f"'{valor}'" if isinstance(valor, str) else str(valor) for valor in fila])
    comando_sql = f"INSERT INTO fact_sales_mstr (Row_ID, Customer_ID, Product_ID, ship_ID, Category_ID, City_ID, Sales, Quantity, Discount, Profit) VALUES ({valores});"
    print(comando_sql)
# Out:
# INSERT INTO fact_sales_mstr (Row_ID, Customer_ID, Product_ID, ship_ID, Category_ID, City_ID, Sales, Quantity, Discount, Profit) VALUES (1, 'CA-2016-152156', 'CG-12520', 'FUR-BO-10001798', 1, 1, 1, 261.96, 2, 0.0, 41.9136);
# INSERT INTO fact_sales_mstr (Row_ID, Customer_ID, Product_ID, ship_ID, Category_ID, City_ID, Sales, Quantity, Discount, Profit) VALUES (3, 'CA-2016-138688', 'DV-13045', 'OFF-LA-10000240', 1, 2, 2, 14.62, 2, 0.0, 6.8714);
# INSERT INTO fact_sales_mstr (Row_ID, Customer_ID, Product_ID, ship_ID, Category_ID, City_ID, Sales, Quantity, Discount, Profit) VALUES (4, 'US-2015-108966', 'SO-20335', 'FUR-TA-10000577', 2, 1, 3, 957.5775, 5, 0.45, -383.031);
# INSERT INTO fact_sales_mstr (Row_ID, Customer_ID, Product_ID, ship_ID, Category_ID, City_ID, Sales, Quantity, Discount, Profit) VALUES (6, 'CA-2014-115812', 'BH-11710', 'FUR-FU-10001487', 2, 1, 2, 48.86, 7, 0.0, 14.1694);
# ...

# %%
with open('Insert_Fact_Sales_mstr.sql', 'w') as archivo_sql:
    for indice, fila in df.iterrows():
        valores = ', '.join([f"'{valor}'" if isinstance(valor, str) else str(valor) for valor in fila])
        comando_sql = f"INSERT INTO fact_sales_mstr (Row_ID, Customer_ID, Product_ID, ship_ID, Category_ID, City_ID, Sales, Quantity, Discount, Profit) VALUES ({valores});\n"
        archivo_sql.write(comando_sql)
