# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./dim_date_mstr.csv', encoding='ISO-8859-1')
df
# Out:
#       Date_ID  Order Date  Year  Month  Day Month_Name
# 0           0  2016-11-08  2016     11    8   November
# 1           1  2016-06-12  2016      6   12       June
# 2           2  2015-10-11  2015     10   11    October
# 3           3  2014-06-09  2014      6    9       June
# 4           4  2017-04-15  2017      4   15      April
# ...       ...         ...   ...    ...  ...        ...
# 1232     1232  2015-12-29  2015     12   29   December
# 1233     1233  2014-04-03  2014      4    3      April
# 1234     1234  2016-06-03  2016      6    3       June
# 1235     1235  2015-04-12  2015      4   12      April
# 1236     1236  2014-01-21  2014      1   21    January
#
# [1237 rows x 6 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1232    False
# 1233    False
# 1234    False
# 1235    False
# 1236    False
# Length: 1237, dtype: bool

# %%
dim_date_mstr = 'dim_date_mstr'

# %%
for indice, fila in df.iterrows():
    valores = ', '.join([f"'{valor}'" if isinstance(valor, str) else str(valor) for valor in fila])
    comando_sql = f"INSERT INTO dim_date_mstr (Date_ID, Order Date, Year, Month, Day, Month_Name) VALUES ({valores});"
    print(comando_sql)
# Out:
# INSERT INTO dim_date_mstr (Date_ID, Order Date, Year, Month, Day, Month_Name) VALUES (0, '2016-11-08', 2016, 11, 8, 'November');
# INSERT INTO dim_date_mstr (Date_ID, Order Date, Year, Month, Day, Month_Name) VALUES (1, '2016-06-12', 2016, 6, 12, 'June');
# INSERT INTO dim_date_mstr (Date_ID, Order Date, Year, Month, Day, Month_Name) VALUES (2, '2015-10-11', 2015, 10, 11, 'October');
# INSERT INTO dim_date_mstr (Date_ID, Order Date, Year, Month, Day, Month_Name) VALUES (3, '2014-06-09', 2014, 6, 9, 'June');
# INSERT INTO dim_date_mstr (Date_ID, Order Date, Year, Month, Day, Month_Name) VALUES (4, '2017-04-15', 2017, 4, 15, 'April');
# INSERT INTO dim_date_mstr (Date_ID, Order Date, Year, Month, Day, Month_Name) VALUES (5, '2016-12-05', 2016, 12, 5, 'December');
# INSERT INTO dim_date_mstr (Date_ID, Order Date, Year, Month, Day, Month_Name) VALUES (6, '2015-11-22', 2015, 11, 22, 'November');
# ...

# %%
with open('insert_dim_date_mstr.sql', 'w') as archivo_sql:
    for indice, fila in df.iterrows():
        valores = ', '.join([f"'{valor}'" if isinstance(valor, str) else str(valor) for valor in fila])
        comando_sql = f"INSERT INTO dim_date_mstr (Date_ID, Order Date, Year, Month, Day, Month_Name) VALUES ({valores});\n"
        archivo_sql.write(comando_sql)
