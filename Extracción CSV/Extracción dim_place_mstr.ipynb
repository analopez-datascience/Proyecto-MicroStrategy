# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./proyecto_superstore_sindup_Id.csv',encoding='ISO-8859-1')
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 2          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 3          6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 4         13  CA-2017-114412   4/15/2017   4/20/2017  Standard Class
# ...      ...             ...         ...         ...             ...
# 5004    9987  CA-2016-125794   9/29/2016   10/3/2016  Standard Class
# 5005    9988  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 5006    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 5007    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 5008    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'ship_ID',
#        'Category_ID', 'City_ID'],
#       dtype='object')

# %%
dim_place_mstr = ['City_ID','City']

# %%
dim_place_mstr = df[dim_place_mstr].copy()

# %%
dim_place_mstr.to_csv('dim_place_mstr.csv', index=False)

# %%
df_place = pd.read_csv('./dim_place_mstr.csv', encoding='utf-8', engine='python')
df_place
# Out:
#       City_ID             City
# 0           1        Henderson
# 1           2      Los Angeles
# 2           3  Fort Lauderdale
# 3           2      Los Angeles
# 4           4          Concord
# ...       ...              ...
# 5004        2      Los Angeles
# 5005      418           Athens
# 5006      101            Miami
# 5007      117       Costa Mesa
# 5008      224      Westminster
#
# [5009 rows x 2 columns]

# %%
df_place.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 5004     True
# 5005     True
# 5006     True
# 5007     True
# 5008     True
# Length: 5009, dtype: bool

# %%
df_place_sin_duplicados = df_place.drop_duplicates()

# %%
df_place_sin_duplicados
# Out:
#       City_ID             City
# 0           1        Henderson
# 1           2      Los Angeles
# 2           3  Fort Lauderdale
# 4           4          Concord
# 5           5          Seattle
# ...       ...              ...
# 4849      527     San Clemente
# 4872      528  San Luis Obispo
# 4904      529       Springdale
# 4922      530             Lodi
# 4947      531            Mason
#
# [531 rows x 2 columns]

# %%
df_place_sin_duplicados.to_csv('dim_place_mstr_sin_duplicados.csv', index=False)

# %%
df_nuevo = pd.read_csv('./dim_place_mstr_sin_duplicados.csv',encoding='ISO-8859-1')
df_nuevo
# Out:
#      City_ID             City
# 0          1        Henderson
# 1          2      Los Angeles
# 2          3  Fort Lauderdale
# 3          4          Concord
# 4          5          Seattle
# ..       ...              ...
# 526      527     San Clemente
# 527      528  San Luis Obispo
# 528      529       Springdale
# 529      530             Lodi
# 530      531            Mason
#
# [531 rows x 2 columns]

# %%
dim_place_mstr_sin = 'dim_place_mstr_sin'

# %%
for indice, fila in df.iterrows():
    valores = ', '.join([f"'{valor}'" if isinstance(valor, str) else str(valor) for valor in fila])
    comando_sql = f"INSERT INTO dim_place_sin  VALUES ({valores});"
    print(comando_sql)
